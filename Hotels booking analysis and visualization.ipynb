# %% [markdown]
# # DATA ANALYSIS (HOTEL BOOKINGS DEMAND)

# %% [markdown]
# This data set contains booking information for a city hotel and a resort hotel,
# and includes information such as when the booking was made, length of stay, the number of adults,
# children, and/or babies,and the number of available parking spaces, among other things.

# %% [markdown]
# # Load data into the dataframe

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:\\Users\\Mphrx\\Downloads\\archive (2)\\hotel_bookings.csv")
data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# The dataset has **119390** rows and **32** columns: <br/>
# **hotel:** The names of the hotel are **City Hotel** and **Resort Hotel** <br/>
# **is_canceled:** Boolean value stored as int64, indicates the hotel is canceled or not <br/>
# **lead_time:** Number of days that elapsed between the entering date of the booking into the PMS and the arrival date <br/>
# **arrival_date:** Information of the arrival date <br/>
# **stay in_weekend_nights:** Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel <br/>
# **stay in_week_nights:** Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel <br/>
# **adults/ children/ babies:** Number of adults/ children/ babies <br/>
# **meal:** Type of meal booked. Categories: <br/>
# - **Undefined/SC** – no meal package <br/>
# - **BB** – Bed & Breakfast <br/>
# - **HB** – Half board (breakfast and one other meal – usually dinner) <br/>
# - **FB** – Full board (breakfast, lunch and dinner)
#
# **country:** Country of origin <br/>
# **market_segment:** Market segment designation. In categories, the term **"TA"** means **"Travel Agents"** and **"TO"** means **"Tour Operators"** <br/>
# **distribution_channel:** Booking distribution channel. The term **"TA"** means **"Travel Agents"** and **"TO"** means **"Tour Operators"** <br/>
# **is_repeated_guest:** Value indicating if the booking name was from a repeated guest (1) or not (0)

# %% [markdown]
# # OVERVIEW

# %% [markdown]
# **Dataset statistics**
# - **Number of rows: $\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;$ 119390**
# - **Number of columns: $\;\;\;\;\;\;\;\;\;\;\;\;\;$ 32**
# - **Missing values: $\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;$ 129425**
# - **Missing values (%): $\;\;\;\;\;\;\;\;\;\;\;\;\;\;$ 3.4%**

# %% [markdown]
# # Number of rows and columns

# %%
data.shape
# Out:
# (119390, 32)

# %% [markdown]
# # Column names

# %%
data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %% [markdown]
# # Column INFO

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# # Column Data Types

# %%
data.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %% [markdown]
# After a quick glimpse of the data set to get an initial understanding of the variables and their formats,
# the next step is to check for the number of missing values in each column.

# %% [markdown]
# # Missing values

# %%
data.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [markdown]
# # Missing values (%)

# %%
(data.isna().sum() / 119390) * 100
# Out:
# hotel                              0.000000
# is_canceled                        0.000000
# lead_time                          0.000000
# arrival_date_year                  0.000000
# arrival_date_month                 0.000000
# arrival_date_week_number           0.000000
# arrival_date_day_of_month          0.000000
# stays_in_weekend_nights            0.000000
# stays_in_week_nights               0.000000
# adults                             0.000000
# children                           0.003350
# babies                             0.000000
# meal                               0.000000
# country                            0.408744
# market_segment                     0.000000
# distribution_channel               0.000000
# is_repeated_guest                  0.000000
# previous_cancellations             0.000000
# previous_bookings_not_canceled     0.000000
# reserved_room_type                 0.000000
# assigned_room_type                 0.000000
# ...

# %% [markdown]
# # Numerical Data

# %%
data.describe().T
# Out:
#                                    count         mean         std      min  \
# is_canceled                     119390.0     0.370416    0.482918     0.00
# lead_time                       119390.0   104.011416  106.863097     0.00
# arrival_date_year               119390.0  2016.156554    0.707476  2015.00
# arrival_date_week_number        119390.0    27.165173   13.605138     1.00
# arrival_date_day_of_month       119390.0    15.798241    8.780829     1.00
# stays_in_weekend_nights         119390.0     0.927599    0.998613     0.00
# stays_in_week_nights            119390.0     2.500302    1.908286     0.00
# adults                          119390.0     1.856403    0.579261     0.00
# children                        119386.0     0.103890    0.398561     0.00
# babies                          119390.0     0.007949    0.097436     0.00
# is_repeated_guest               119390.0     0.031912    0.175767     0.00
# ...

# %% [markdown]
# # Categorical Data

# %%
data.describe(include = "object").T
# Out:
#                           count unique         top    freq
# hotel                    119390      2  City Hotel   79330
# arrival_date_month       119390     12      August   13877
# meal                     119390      5          BB   92310
# country                  118902    177         PRT   48590
# market_segment           119390      8   Online TA   56477
# distribution_channel     119390      5       TA/TO   97870
# reserved_room_type       119390     10           A   85994
# assigned_room_type       119390     12           A   74053
# deposit_type             119390      3  No Deposit  104641
# customer_type            119390      4   Transient   89613
# reservation_status       119390      3   Check-Out   75166
# reservation_status_date  119390    926  2015-10-21    1461

# %% [markdown]
# # Description of Whole Data

# %%
data.describe(include = "all")
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %% [markdown]
# # Data Cleaning

# %%
data["children"] = data["children"].fillna(0)
data["country"] = data["country"].fillna("Undefined")
data["agent"] = data["agent"].fillna(0)
data["company"] = data["company"].fillna(0)
data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# **Now there are no null values. Now look for unique values in each columns.**

# %%
print ('Hotel                :', data.hotel.unique())
print ('\nYear                 :', data.arrival_date_year.unique())
print ('\nMonth                :',data.arrival_date_month.unique())
print ('\nMeal                 :', data.meal.unique())
print ('\nCountry              :', data.country.unique())
print ('\nMarket Segment       :', data.market_segment.unique())
print ('\nDistribution Channel :', data.distribution_channel.unique())
print ('\nReserved Room Type   :', data.reserved_room_type.unique())
print ('\nAssigned Room Type   :', data.assigned_room_type.unique())
print ('\nDeposit Type         :', data.deposit_type.unique())
print ('\nCustomer Type        :', data.customer_type.unique())
print ('\nReservation Status   :', data.reservation_status.unique())
# Out:
# Hotel                : ['Resort Hotel' 'City Hotel']
#
# Year                 : [2015 2016 2017]
#
# Month                : ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
#
# Meal                 : ['BB' 'FB' 'HB' 'SC' 'Undefined']
#
# Country              : ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' 'Undefined' 'ROU' 'NOR' 'OMN' 'ARG'
#  'POL' 'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS'
#  'EST' 'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX'
#  'MAR' 'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF'
#  'AGO' 'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN'
#  'JAM' 'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL'
#  'GGY' 'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL'
#  'SEN' 'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA'
# ...

# %% [markdown]
# # Replacing 1's and 0's with "YES" AND " NO" in Columns [is_canceled & is_repeated_guest]

# %%
data["is_canceled"] = data["is_canceled"].replace({1:"Yes", 0:"No"})
data["is_repeated_guest"] = data["is_repeated_guest"].replace({1:"Yes", 0:"No"})
print(data.is_canceled.unique())
print(data.is_repeated_guest.unique())
# Out:
# ['No' 'Yes']
# ['No' 'Yes']

# %% [markdown]
# # Which hotels contains maximum of bookings?

# %%
data.hotel.agg(["value_counts"])
# Out:
#               value_counts
# City Hotel           79330
# Resort Hotel         40060

# %%
hotel = ["City Hotel", "Resort Hotel"]
booking = data.hotel.value_counts()
color = ["r", "k"]

plt.figure(figsize = (10, 7))
plt.pie(booking, labels = hotel, colors = color, explode = (0, 0.1), textprops = {'color':"w"}, autopct = "%.2f%%", shadow = True, startangle = 90)

plt.legend()

plt.show();

# %% [markdown]
# **City Hotels** contains maximum of bookings.

# %% [markdown]
# # Which hotel have maximum number of cancellation of bookings?

# %%
data.groupby(["hotel"])["is_canceled"].agg(["value_counts"])
# Out:
#                           value_counts
# hotel        is_canceled
# City Hotel   No                  46228
#              Yes                 33102
# Resort Hotel No                  28938
#              Yes                 11122

# %%
sns.countplot(x = "hotel", hue = "is_canceled", data = data);

# %% [markdown]
# **City Hotel** contains maximum number of cancellation of bookings.

# %% [markdown]
# # Count of previous cancellations per year in each hotel

# %%
data.groupby(["hotel", "arrival_date_year"])["previous_cancellations"].agg(["value_counts"])
# Out:
#                                                        value_counts
# hotel        arrival_date_year previous_cancellations
# City Hotel   2015              0                               9980
#                                1                               3684
#                                2                                 15
#                                11                                 2
#                                21                                 1
#              2016              0                              36645
#                                1                               1338
#                                3                                 47
#                                2                                 37
#                                11                                33
#                                13                                12
#                                5                                 11
# ...

# %% [markdown]
# # Count of previous bookings which are not canceled per year in each hotel

# %%
data.groupby(["hotel", "arrival_date_year"])["previous_bookings_not_canceled"].agg(["value_counts"])
# Out:
#                                                                value_counts
# hotel        arrival_date_year previous_bookings_not_canceled
# City Hotel   2015              0                                      13548
#                                1                                         65
#                                2                                         24
#                                3                                         12
#                                5                                          7
# ...                                                                     ...
# Resort Hotel 2017              23                                         1
#                                26                                         1
#                                28                                         1
#                                29                                         1
#                                30                                         1
# ...

# %% [markdown]
# # Count of previous cancellations by repeated guests

# %%
data[["previous_cancellations"]][data["is_repeated_guest"] == "Yes"].agg(["value_counts"])
# Out:
#    previous_cancellations
#              value_counts
# 0                    2883
# 1                     693
# 2                      76
# 3                      52
# 4                      31
# 11                     27
# 5                      19
# 6                      16
# 13                     12
# 21                      1

# %%
data[["previous_cancellations"]][data["is_repeated_guest"] == "Yes"].agg(["value_counts"]).plot(kind = "bar")
plt.xticks(rotation = 0);

# %% [markdown]
# # Analysing Preference of guests, what they basically prefer?

# %%
data["meal"].agg(["value_counts"])
# Out:
#            value_counts
# BB                92310
# HB                14463
# SC                10650
# Undefined          1169
# FB                  798

# %%
meal = ["BB", "HB", "SC", "Undefined", "FB"]
values = data.meal.value_counts()

plt.figure(figsize = (10, 7))
plt.pie(values, labels = meal, explode = (0.1, 0, 0.1, 0.2, 0.3), autopct = "%.2f%%",startangle = 90)

plt.legend()

plt.show();

# %% [markdown]
# We can conclude from here that most of the customers prefer **BB (Bed & Breakfast)**.

# %% [markdown]
# # What are the Adults favorite and least favorite meal?

# %%
data.iloc[np.where((data["adults"] > 0) & (data["meal"] != "Undefined"))]["meal"].agg(["value_counts"])
# Out:
#     value_counts
# BB         92020
# HB         14454
# SC         10546
# FB           798

# %%
meal = ["BB", "HB", "SC", "FB"]
values = [92020, 14454, 10546, 798]

plt.figure(figsize = (10, 7))
plt.pie(values, labels = meal, explode = (0.1, 0, 0.1, 0.2), autopct = "%.2f%%", startangle = 90)

plt.legend()

plt.show();

# %% [markdown]
# # What are the Children favorite and least favorite meals?

# %%
data.iloc[np.where((data["children"] > 0) & (data["meal"] != "Undefined"))]["meal"].agg(["value_counts"])
# Out:
#     value_counts
# BB          7079
# HB          1246
# SC           156
# FB            66

# %%
meal = ["BB", "HB", "SC", "FB"]
values = [7079, 1246, 156, 66]

plt.figure(figsize = (10, 7))
plt.pie(values, labels = meal, explode = (0.1, 0, 0.1, 0.2), autopct = "%.2f%%", startangle = 90)

plt.legend()

plt.show();

# %% [markdown]
# # What are the Babies favorite and least favorite meals?

# %%
data.iloc[np.where((data["babies"] > 0) & (data["meal"] != "Undefined"))]["meal"].agg(["value_counts"])
# Out:
#     value_counts
# BB           662
# HB           178
# SC            37
# FB            24

# %%
meal = ["BB", "HB", "SC", "FB"]
values = [662, 178, 37, 24]

plt.figure(figsize = (10, 7))
plt.pie(values, labels = meal, explode = (0.1, 0, 0.1, 0.2), autopct = "%.2f%%", startangle = 90)

plt.legend()

plt.show();

# %% [markdown]
# # Which  is the most busy year?

# %%
data.arrival_date_year.agg(["value_counts"])
# Out:
#       value_counts
# 2016         56707
# 2017         40687
# 2015         21996

# %%
year = [2016, 2017, 2015]
counts = data.arrival_date_year.value_counts()

plt.figure(figsize = (5, 7))
plt.pie(counts, explode = (0.1, 0.1, 0.1), labels = year, autopct = "%.2f%%", shadow = True, startangle = 90)

plt.show();

# %% [markdown]
# we can conclude from here that most busy year is 2016

# %% [markdown]
# # How many guests arrived year-wise?

# %%
data.groupby(["hotel"])["arrival_date_year"].agg(["value_counts"])
# Out:
#                                 value_counts
# hotel        arrival_date_year
# City Hotel   2016                      38140
#              2017                      27508
#              2015                      13682
# Resort Hotel 2016                      18567
#              2017                      13179
#              2015                       8314

# %%
sns.countplot(x = "hotel", hue = "arrival_date_year", data = data, order = ["City Hotel", "Resort Hotel"]);

# %% [markdown]
# # Which are the most busiest month?

# %%
data.groupby(["hotel"])["arrival_date_month"].agg(["value_counts"])
# Out:
#                                  value_counts
# hotel        arrival_date_month
# City Hotel   August                      8983
#              May                         8232
#              July                        8088
#              June                        7894
#              October                     7605
#              April                       7480
#              September                   7400
#              March                       6458
#              February                    4965
#              November                    4357
#              December                    4132
#              January                     3736
# Resort Hotel August                      4894
#              July                        4573
#              April                       3609
#              May                         3559
#              October                     3555
#              March                       3336
#              September                   3108
# ...

# %% [markdown]
# Business managers should make the strategies with respect to these months to get more bookings

# %% [markdown]
# # How many guests arrived month-wise per year?

# %%
data.groupby(["hotel", "arrival_date_year"])["arrival_date_month"].agg(["value_counts"])
# Out:
#                                                    value_counts
# hotel        arrival_date_year arrival_date_month
# City Hotel   2015              September                   3529
#                                October                     3386
#                                August                      2480
#                                December                    1654
#                                July                        1398
#                                November                    1235
#              2016              October                     4219
#                                June                        3923
#                                September                   3871
#                                May                         3676
#                                April                       3561
#                                August                      3378
#                                July                        3131
# ...

# %% [markdown]
# insight : peak season month
# City :
# 2015 - oct (means higest booking done in oct )
# 2016 - sept
# 2017 - may
# resort :
# 2015 - oct
# 2016 - oct
# 2017 - may

# %% [markdown]
# # How many guests arrived date-wise?

# %%
data.groupby(["hotel", "arrival_date_day_of_month"])["arrival_date_day_of_month"].agg(["count"])
# Out:
#                                         count
# hotel        arrival_date_day_of_month
# City Hotel   1                           2332
#              2                           2667
#              3                           2530
#              4                           2461
#              5                           2857
# ...                                       ...
# Resort Hotel 27                          1265
#              28                          1276
#              29                          1214
#              30                          1473
#              31                           856
#
# [62 rows x 1 columns]

# %% [markdown]
# # Guest arrival trend week wise is as follows

# %%
data1=data[data["is_canceled"]== "No"]
data1
# Out:
#                hotel is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel          No        342               2015
# 1       Resort Hotel          No        737               2015
# 2       Resort Hotel          No          7               2015
# 3       Resort Hotel          No         13               2015
# 4       Resort Hotel          No         14               2015
# ...              ...         ...        ...                ...
# 119385    City Hotel          No         23               2017
# 119386    City Hotel          No        102               2017
# 119387    City Hotel          No         34               2017
# 119388    City Hotel          No        109               2017
# 119389    City Hotel          No        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
week1=len(data1[(data1["arrival_date_day_of_month"]>=1) & (data1["arrival_date_day_of_month"]<=7)])

week2=len(data1[(data1["arrival_date_day_of_month"]>=8) & (data1["arrival_date_day_of_month"]<=14)])

week3=len(data1[(data1["arrival_date_day_of_month"]>=15) & (data1["arrival_date_day_of_month"]<=21)])

week4=len(data1[(data1["arrival_date_day_of_month"]>=22) & (data1["arrival_date_day_of_month"]<=31)])

l=[]
l.append(week1)
l.append(week2)
l.append(week3)
l.append(week4)
s=sorted(l)
print(s)
# Out:
# [16950, 16992, 17856, 23368]

# %% [markdown]
# insight : maximum people visted the hotel in week4 (last week) of month
# so business heads can plan business strategies for last happy week of months

# %% [markdown]
# # Which type of customers are more likely to cancel the booking?

# %%
data["customer_type"][data["is_canceled"] == "Yes"].agg(["value_counts"])
# Out:
#                  value_counts
# Transient               36514
# Transient-Party          6389
# Contract                 1262
# Group                      59

# %%
data["customer_type"][data["is_canceled"] == "Yes"].agg(["value_counts"]).plot(kind = "bar");

# %% [markdown]
# **Transient** customer type are more likely to cancel the booking more than the other types.

# %% [markdown]
# # Deposit Type hotel-wise

# %%
data.groupby(["hotel"])["deposit_type"].agg(["value_counts"])
# Out:
#                            value_counts
# hotel        deposit_type
# City Hotel   No Deposit           66442
#              Non Refund           12868
#              Refundable              20
# Resort Hotel No Deposit           38199
#              Non Refund            1719
#              Refundable             142

# %%
deposit = ["No Deposit", "Non Refund", "Refundable"]
count1 = [66442, 12868, 20]
count2 = [38199, 1719, 142]

plt.figure(figsize = (10, 15))
plt.subplot(1, 2, 1)  
plt.pie(count1, labels = deposit, explode = (0.1, 0.1, 0.2), autopct = "%.2f%%", startangle = 90)
plt.title("City Hotel", y = -0.05)

plt.subplot(1, 2, 2)  
plt.pie(count2, labels = deposit, explode = (0.1, 0.1, 0.2), autopct = "%.2f%%", startangle = 90)
plt.title("Resort Hotel", y = -0.05)

plt.show();

# %% [markdown]
# # Count of deposit type which are cancelled in each hotel

# %%
data["deposit_type"][data["is_canceled"] == "Yes"].agg(["value_counts"])
# Out:
#             value_counts
# No Deposit         29694
# Non Refund         14494
# Refundable            36

# %%
deposit = ["No Deposit", "Non Refund", "Refundable"]
count = [29694, 14494, 36]

plt.figure(figsize = (5, 7)) 
plt.pie(count, labels = deposit, explode = (0.1, 0.1, 0.2), autopct = "%.2f%%", startangle = 90)

plt.show();

# %% [markdown]
# # Number of guests who had not cancelled their booking?¶

# %%
data[data["is_canceled"] =="No"]["country"].agg(["value_counts"])
# Out:
#      value_counts
# PRT         21071
# GBR          9676
# FRA          8481
# ESP          6391
# DEU          6069
# ..            ...
# BHR             1
# DJI             1
# MLI             1
# NPL             1
# FRO             1
#
# [166 rows x 1 columns]

# %% [markdown]
# # From where the most guests coming?

# %%
data["country"].agg(["value_counts"])
# Out:
#      value_counts
# PRT         48590
# GBR         12129
# FRA         10415
# ESP          8568
# DEU          7287
# ..            ...
# DJI             1
# BWA             1
# HND             1
# VGB             1
# NAM             1
#
# [178 rows x 1 columns]

# %% [markdown]
#  Mostly guests are coming from PRT.

# %% [markdown]
# # How many guests coming from mentioned countries in Resort Hotel?

# %%
data["country"][data["hotel"] == "Resort Hotel"].agg(["value_counts"])
# Out:
#      value_counts
# PRT         17630
# GBR          6814
# ESP          3957
# IRL          2166
# FRA          1611
# ..            ...
# BIH             1
# MUS             1
# COM             1
# UGA             1
# DJI             1
#
# [126 rows x 1 columns]

# %% [markdown]
# # How many guests coming from mentioned countries in City Hotel?

# %%
data["country"][data["hotel"] == "City Hotel"].agg(["value_counts"])
# Out:
#      value_counts
# PRT         30960
# FRA          8804
# DEU          6084
# GBR          5315
# ESP          4611
# ..            ...
# UMI             1
# VGB             1
# NIC             1
# ZMB             1
# COM             1
#
# [167 rows x 1 columns]

# %% [markdown]
# # Maximum number of stays in week nights in each hotel?

# %%
data.groupby(["hotel"])["stays_in_week_nights"].agg(["max"])
# Out:
#               max
# hotel
# City Hotel     41
# Resort Hotel   50

# %% [markdown]
# # Maximum number of stays in weekend nights in each hotel?

# %%
data.groupby(["hotel"])["stays_in_weekend_nights"].agg(["max"])
# Out:
#               max
# hotel
# City Hotel     16
# Resort Hotel   19

# %% [markdown]
# # From where most of the bookings were made?

# %%
data.groupby(["hotel"])["market_segment"].agg(["value_counts"])
# Out:
#                              value_counts
# hotel        market_segment
# City Hotel   Online TA              38748
#              Offline TA/TO          16747
#              Groups                 13975
#              Direct                  6093
#              Corporate               2986
#              Complementary            542
#              Aviation                 237
#              Undefined                  2
# Resort Hotel Online TA              17729
#              Offline TA/TO           7472
#              Direct                  6513
#              Groups                  5836
#              Corporate               2309
#              Complementary            201

# %%
city = ["Online TA", "Offline TA/TO", "Groups", "Direct", "Corporate", "Complementary", "Aviation", "Undefined"]
count1 = [38748, 16747, 13975, 6093, 2986, 542, 237, 2]
resort = ["Online TA", "Offline TA/TO", "Direct", "Groups",  "Corporate", "Complementary"]
count2 = [17729, 7472, 6513, 5836, 2309, 201]

plt.figure(figsize = (10, 15))
plt.subplot(1, 2, 1)  
plt.pie(count1, labels = city, explode = (0.1, 0, 0.1, 0, 0.1, 0, 0.2, 0.3), autopct = "%.2f%%", startangle = 90)
plt.title("City Hotel", y = -0.05)

plt.subplot(1, 2, 2)  
plt.pie(count2, labels = resort, explode = (0.1, 0, 0.1, 0, 0.2, 0), autopct = "%.2f%%", startangle = 90)
plt.title("Resort Hotel", y = -0.05)

plt.show();

# %% [markdown]
# Most of the bookings made were online in both the hotels.

# %% [markdown]
# # Market segment country-wise

# %%
data.groupby(["market_segment"])[["country"]].agg(["value_counts"])
# Out:
#                             country
#                        value_counts
# market_segment country
# Aviation       PRT              105
#                BEL               22
#                ITA               21
#                AUT               15
#                GRC               14
# ...                             ...
# Online TA      TGO                1
#                UMI                1
#                VGB                1
#                ZWE                1
# Undefined      PRT                2
#
# [559 rows x 1 columns]

# %% [markdown]
# # Which Distribution Channel is mostly prefered?

# %%
data.groupby(["hotel"])["distribution_channel"].agg(["value_counts"])
# Out:
#                                    value_counts
# hotel        distribution_channel
# City Hotel   TA/TO                        68945
#              Direct                        6780
#              Corporate                     3408
#              GDS                            193
#              Undefined                        4
# Resort Hotel TA/TO                        28925
#              Direct                        7865
#              Corporate                     3269
#              Undefined                        1

# %%
sns.countplot(x = "hotel", hue = "distribution_channel", data = data);

# %% [markdown]
# Most of the bookings were made through travel agent/travel operators.

# %% [markdown]
# # What is the reservation status per year in each hotel?

# %%
data.groupby(["hotel", "arrival_date_year"])["reservation_status"].agg(["value_counts"])
# Out:
#                                                    value_counts
# hotel        arrival_date_year reservation_status
# City Hotel   2015              Check-Out                   7678
#                                Canceled                    5882
#                                No-Show                      122
#              2016              Check-Out                  22733
#                                Canceled                   14852
#                                No-Show                      555
#              2017              Check-Out                  15817
#                                Canceled                   11452
#                                No-Show                      239
# Resort Hotel 2015              Check-Out                   6176
#                                Canceled                    2069
#                                No-Show                       69
#              2016              Check-Out                  13637
# ...

# %%
status = ["Check-Out", "Canceled", "No-Show"]
count1 = [7678, 5882, 122]
count2 = [22733, 14852, 555]
count3 = [15817, 11452, 239]
count4 = [6176, 2039, 69]
count5 = [13637, 4817, 113]
count6 = [9125, 3945, 109]

plt.figure(figsize = (15, 10))
plt.subplot(2, 3, 1)  
plt.pie(count1, labels = status, explode = (0.1, 0, 0.1), autopct = "%.2f%%", startangle = 90)
plt.title("2015", y = -0.05)

plt.subplot(2, 3, 2)  
plt.pie(count2, labels = status, explode = (0.1, 0, 0.1), autopct = "%.2f%%", startangle = 90)
plt.title("2016", y = -0.05)

plt.subplot(2, 3, 3)  
plt.pie(count3, labels = status, explode = (0.1, 0, 0.1), autopct = "%.2f%%", startangle = 90)
plt.title("2017", y = -0.05)

plt.subplot(2, 3, 4)  
plt.pie(count4, labels = status, explode = (0.1, 0, 0.1), autopct = "%.2f%%", startangle = 90)
plt.title("2015", y = -0.05)

plt.subplot(2, 3, 5)  
plt.pie(count5, labels = status, explode = (0.1, 0, 0.1), autopct = "%.2f%%", startangle = 90)
plt.title("2016", y = -0.05)

plt.subplot(2, 3, 6)  
plt.pie(count6, labels = status, explode = (0.1, 0, 0.1), autopct = "%.2f%%", startangle = 90)
plt.title("2017", y = -0.05)

plt.show();

# %% [markdown]
# # How many people change their bookings in each hotel?

# %%
data.groupby(["hotel"])["booking_changes"].agg(["value_counts"])
# Out:
#                               value_counts
# hotel        booking_changes
# City Hotel   0                       69062
#              1                        7232
#              2                        2244
#              3                         467
#              4                         194
#              5                          46
#              6                          31
#              7                          19
#              8                           9
#              14                          5
#              9                           4
#              10                          3
#              13                          3
#              15                          3
#              11                          2
#              12                          1
#              16                          1
#              17                          1
#              18                          1
#              20                          1
# ...

# %% [markdown]
# # Change column name

# %% [markdown]
# change the column **[adr]** as **average daily rate**:

# %%
data.rename(columns = {"adr":"average_daily_rate"}, inplace = True)

# %%
data.groupby("hotel").sum().average_daily_rate
# Out:
# hotel
# City Hotel      8353803.24
# Resort Hotel    3803814.36
# Name: average_daily_rate, dtype: float64

# %%
data.groupby("arrival_date_year").sum().average_daily_rate
# Out:
# arrival_date_year
# 2015    1917578.62
# 2016    5575764.71
# 2017    4664274.27
# Name: average_daily_rate, dtype: float64

# %%
data["average_daily_rate"].mean()
# Out:
# 101.83112153446453

# %%
data["average_daily_rate"].sum()
# Out:
# 12157617.599999998

# %% [markdown]
# # How many guests visited hotel more than once?

# %%
data.groupby(["hotel"])["is_repeated_guest"].agg(["value_counts"])
# Out:
#                                 value_counts
# hotel        is_repeated_guest
# City Hotel   No                        77298
#              Yes                        2032
# Resort Hotel No                        38282
#              Yes                        1778

# %%
sns.countplot(x = "hotel", hue = "is_repeated_guest", data = data);

# %% [markdown]
# In **City Hotel** 2032 and in **Resort Hotel** 1778 guests visited more than once which shows the overall service of the hotels was good.

# %% [markdown]
# # Requirement of parking spaces

# %%
data.groupby(["hotel"])["required_car_parking_spaces"].agg(["value_counts"])
# Out:
#                                           value_counts
# hotel        required_car_parking_spaces
# City Hotel   0                                   77404
#              1                                    1921
#              2                                       3
#              3                                       2
# Resort Hotel 0                                   34570
#              1                                    5462
#              2                                      25
#              8                                       2
#              3                                       1

# %% [markdown]
# Most of the guests not required parking spaces.

# %% [markdown]
# # What is the maximum lead time in each hotels?

# %%
data.groupby(["hotel"])["lead_time"].agg(["max"])
# Out:
#               max
# hotel
# City Hotel    629
# Resort Hotel  737

# %% [markdown]
# # Numbers of guests who did not  booked hotels in advance?

# %%
data["lead_time"][data["lead_time"] == 0].agg(["value_counts"])
# Out:
#    value_counts
# 0          6345

# %% [markdown]
# # Which room types are mostly reserved?

# %%
data.groupby(["hotel"])["reserved_room_type"].agg(["value_counts"])
# Out:
#                                  value_counts
# hotel        reserved_room_type
# City Hotel   A                          62595
#              D                          11768
#              F                           1791
#              E                           1553
#              B                           1115
#              G                            484
#              C                             14
#              P                             10
# Resort Hotel A                          23399
#              D                           7433
#              E                           4982
#              G                           1610
#              F                           1106
#              C                            918
#              H                            601
#              L                              6
#              B                              3
#              P                              2

# %%
sns.countplot(x = "hotel", hue = "reserved_room_type", data = data);

# %% [markdown]
# **Room Type A** is mostly reserved in both the hotels.

# %% [markdown]
# # How many visitors get room which they reserved?¶

# %%
data["reserved_room_type"].agg(["count"])
# Out:
# count    119390
# Name: reserved_room_type, dtype: int64

# %%
data["reserved_room_type"][data["reserved_room_type"] == data["assigned_room_type"]].agg(["count"])
# Out:
# count    104473
# Name: reserved_room_type, dtype: int64

# %% [markdown]
# Out of **119390** only **104473** visitors got their room which they reserved.

# %% [markdown]
# # Room-wise Data

# %%
data[data["reserved_room_type"] == data["assigned_room_type"]][["reserved_room_type", "assigned_room_type"]].agg(["value_counts"])
# Out:
#   reserved_room_type assigned_room_type
#         value_counts       value_counts
# A              73598              73598
# D              17736              17736
# E               5923               5923
# F               2707               2707
# G               2041               2041
# B                988                988
# C                883                883
# H                584                584
# P                 12                 12
# L                  1                  1

# %% [markdown]
# # How many special requests received by each hotel?

# %%
data.groupby(["hotel"])["total_of_special_requests"].agg(["value_counts"])
# Out:
#                                         value_counts
# hotel        total_of_special_requests
# City Hotel   0                                 47957
#              1                                 21420
#              2                                  8142
#              3                                  1587
#              4                                   198
#              5                                    26
# Resort Hotel 0                                 22361
#              1                                 11806
#              2                                  4827
#              3                                   910
#              4                                   142
#              5                                    14

# %% [markdown]
# # Days in waiting list hotel-wise

# %%
data.groupby(["hotel"])["days_in_waiting_list"].agg(["value_counts"])
# Out:
#                                    value_counts
# hotel        days_in_waiting_list
# City Hotel   0                            75887
#              39                             226
#              58                             164
#              44                             140
#              31                             127
# ...                                         ...
# Resort Hotel 93                               1
#              105                              1
#              109                              1
#              116                              1
#              142                              1
#
# [159 rows x 1 columns]

# %% [markdown]
# # How many adults having children and babies?

# %%
data[(data["adults"] > 0) & (data["children"] > 0) & (data["babies"] > 0)]["adults"].agg(["count"])
# Out:
# count    172
# Name: adults, dtype: int64

# %% [markdown]
# # How many adults having children only?

# %%
data[(data["adults"] > 0) & (data["children"] > 0)]["children"].agg(["count"])
# Out:
# count    8367
# Name: children, dtype: int64

# %% [markdown]
# # How many adults having babies only?

# %%
data[(data["adults"] > 0) & (data["babies"] > 0)]["babies"].agg(["count"])
# Out:
# count    914
# Name: babies, dtype: int64

# %% [markdown]
# # Reservation Status

# %%
print (data.reservation_status.unique())
# Out:
# ['Check-Out' 'Canceled' 'No-Show']

# %% [markdown]
# # Most Check-Out dates in 2015, 2016, 2017

# %%
data.iloc[np.where((data["reservation_status"] == "Check-Out") & (data["arrival_date_year"] == 2015))][["arrival_date_year", "reservation_status", "reservation_status_date"]].value_counts().idxmax()
# Out:
# (2015, 'Check-Out', '2015-12-08')

# %%
data.iloc[np.where((data["reservation_status"] == "Check-Out") & (data["arrival_date_year"] == 2016))][["arrival_date_year", "reservation_status", "reservation_status_date"]].value_counts().idxmax()
# Out:
# (2016, 'Check-Out', '2016-06-26')

# %%
data.iloc[np.where((data["reservation_status"] == "Check-Out") & (data["arrival_date_year"] == 2017))][["arrival_date_year", "reservation_status", "reservation_status_date"]].value_counts().idxmax()
# Out:
# (2017, 'Check-Out', '2017-01-19')

# %% [markdown]
# # Most cancelled dates in 2015, 2016, 2017

# %%
data.iloc[np.where((data["reservation_status"] == "Canceled") & (data["arrival_date_year"] == 2015))][["arrival_date_year", "reservation_status", "reservation_status_date"]].value_counts().idxmax()
# Out:
# (2015, 'Canceled', '2015-07-06')

# %%
data.iloc[np.where((data["reservation_status"] == "Canceled") & (data["arrival_date_year"] == 2016))][["arrival_date_year", "reservation_status", "reservation_status_date"]].value_counts().idxmax()
# Out:
# (2016, 'Canceled', '2015-10-21')

# %%
data.iloc[np.where((data["reservation_status"] == "Canceled") & (data["arrival_date_year"] == 2017))][["arrival_date_year", "reservation_status", "reservation_status_date"]].value_counts().idxmax()
# Out:
# (2017, 'Canceled', '2016-11-25')

# %% [markdown]
# # Most No-Show dates in 2015, 2016, 2017

# %%
data.iloc[np.where((data["reservation_status"] == "No-Show") & (data["arrival_date_year"] == 2015))][["arrival_date_year", "reservation_status", "reservation_status_date"]].value_counts().idxmax()
# Out:
# (2015, 'No-Show', '2015-12-25')

# %%
data.iloc[np.where((data["reservation_status"] == "No-Show") & (data["arrival_date_year"] == 2016))][["arrival_date_year", "reservation_status", "reservation_status_date"]].value_counts().idxmax()
# Out:
# (2016, 'No-Show', '2016-02-28')

# %%
data.iloc[np.where((data["reservation_status"] == "No-Show") & (data["arrival_date_year"] == 2017))][["arrival_date_year", "reservation_status", "reservation_status_date"]].value_counts().idxmax()
# Out:
# (2017, 'No-Show', '2017-02-25')

# %%
sns.pairplot(data);
